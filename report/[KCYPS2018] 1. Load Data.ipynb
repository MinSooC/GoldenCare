# %% [markdown]
# # **[KCYPS 2018] 데이터 불러오기**

# %% [markdown]
# # **Settings**

# %%
# system
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/메타버스 아카데미/메타버스아카데미 6월 프로젝트/data/KCYPS2018')

import warnings
warnings.filterwarnings('ignore')                                    # warning 출력 false

# dataframe
import re
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# ## **1) 데이터 압축 풀기**

# %%
# 압축 풀기
# ! mkdir KCYPS2018-e4
# ! unzip KCYPS2018-e4.zip -d ./KCYPS2018-e4

# %%
# 압축 풀기
# ! mkdir KCYPS2018-m1
# ! unzip KCYPS2018-m1.zip -d ./KCYPS2018-m1

# %% [markdown]
# ## **2) 데이터 불러오기**

# %% [markdown]
# ### **변수 설명 데이터**

# %%
# 패널 데이터의 변수 정보를 불러오는 함수이다.
def load_codebooks(file_path):
    codebooks = {'e4':'', 'm1':'', 'p':''}
    sheet_names = ['LAYOUT_e', 'LAYOUT_m', 'LAYOUT_p']

    for dic_name, sheet in zip(codebooks.keys(), sheet_names):
        temp = pd.read_excel(file_path, sheet_name=sheet,
                             skiprows=3, usecols=[i for i in range(1,8)]).reset_index(drop=True)
        temp = temp.iloc[1:,:]
        codebooks[dic_name] = temp

    with open('./datasets/codebooks.pkl', 'wb') as f:
        pickle.dump(codebooks, f)

    print(f'>>> codebooks 저장 완료! -> list={list(codebooks.keys())}')

    return codebooks

# %%
# codebook 불러오기
file_path = 'KCYPS2018 Codebook.xlsx'
codebooks = load_codebooks(file_path)
# Out:
# >>> codebooks 저장 완료! -> list=['e4', 'm1', 'p']

# %%
codebooks['e4'].head(5)
# Out:
#   대영역 중영역 소영역 조사항목 하위요인       변수설명       변수명
# 1   -   -   -    -    -      가구 ID       HID
# 2   -   -   -    -    -      개인 ID       PID
# 3   -   -   -    -    -       학교코드     SCLID
# 4   -   -   -    -    -  온라인 조사 여부   YONLINE
# 5   -   -   -    -    -  횡단면_원 가중치  WEIGHTA1

# %% [markdown]
# ### **원 데이터 불러오기**

# %%
# 패널 데이터를 불러오는 함수이다.
def load_data(codebooks):
    data = {}
    print('info = {e4: 초등4, m1: 중등1, p: 보호자}')
    print('-' * 60)
    for survey in ['e4', 'm1']:
        for year in range(1, 5):
            file_path = f'./KCYPS2018-{survey}/'

            # 각 파일 불러오기
            try:
                data1 = pd.read_csv(file_path + f'KCYPS2018{survey}Yw{year}.csv', encoding='CP949')
                data2 = pd.read_csv(file_path + f'KCYPS2018{survey}Pw{year}.csv', encoding='CP949')
            except:
                data1 = pd.read_csv(file_path + f'KCYPS2018{survey}Yw{year}.csv')
                data2 = pd.read_csv(file_path + f'KCYPS2018{survey}Pw{year}.csv')
            print(f'data Y size = {data1.shape} data P size = {data2.shape}')

            # 데이터 타입 변경
            data1 = data1.astype({'HID':str, 'PID':str})
            data2 = data2.astype({'HID':str, 'PID':str})

            # ID 변수 생성
            data1['ID'] = data1['HID'] + '-' + data1['PID'] + '-' + str(year)
            data2['ID'] = data2['HID'] + '-' + data2['PID'] + '-' + str(year)

            # ID 변수 생성
            data1['ID_w'] = data1['HID'] + '-' + data1['PID']
            data2['ID_w'] = data2['HID'] + '-' + data2['PID']

            # 데이터 변수에 시계열 표현 제거 w1, w2, w3, w4
            data_cols1, data_cols2 = [], []
            for col1 in data1.columns:
                if col1[-2] == 'w':
                    col1 = col1[:-2]
                data_cols1.append(col1)

            for col2 in data2.columns:
                if col2[-2] == 'w':
                    col2 = col2[:-2]
                data_cols2.append(col2)

            # 데이터 변수 변경
            data1.columns = data_cols1
            data2.columns = data_cols2

            data[f'{survey}Yw{year}'] = data1
            data[f'{survey}Pw{year}'] = data2
            print(f'>>> {survey}_{year}차 조사 데이터 불러오기 완료')
            print('-' * 60)

    # 저장
    with open(f'./datasets/data_dict.pkl', 'wb') as f:
        pickle.dump(data, f)

    print('>>> data 저장 완료!')
    print(f'-> list={list(data.keys())}')

    return data

# %%
# 데이터 불러오기
data = load_data(codebooks)
# Out:
# info = {e4: 초등4, m1: 중등1, p: 보호자}
# ------------------------------------------------------------
# data Y size = (2607, 239) data P size = (2607, 209)
# >>> e4_1차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2607, 266) data P size = (3518, 196)
# >>> e4_2차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2607, 315) data P size = (3597, 249)
# >>> e4_3차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2607, 432) data P size = (3552, 241)
# >>> e4_4차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2590, 350) data P size = (2590, 209)
# >>> m1_1차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2590, 378) data P size = (3628, 196)
# >>> m1_2차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2590, 427) data P size = (3505, 249)
# >>> m1_3차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# data Y size = (2590, 433) data P size = (3438, 241)
# >>> m1_4차 조사 데이터 불러오기 완료
# ------------------------------------------------------------
# >>> data 저장 완료!
# -> list=['e4Yw1', 'e4Pw1', 'e4Yw2', 'e4Pw2', 'e4Yw3', 'e4Pw3', 'e4Yw4', 'e4Pw4', 'm1Yw1', 'm1Pw1', 'm1Yw2', 'm1Pw2', 'm1Yw3', 'm1Pw3', 'm1Yw4', 'm1Pw4']

# %%
data['e4Pw1'].head(5)
# Out:
#   HID PID  PARENT  PYBRT1A  PYBRT1B  PYGENDER  PINCOME  PINCOME1  PYBRP1  \
# 0   1   1       1     2008        2         2      7.0       3.0       1
# 1   2   1       1     2008       10         2      5.0       3.0       1
# 2   3   1       1     2008        6         1      9.0       3.0       1
# 3   3   2       1     2008        6         1      9.0       3.0       1
# 4   4   1       1     2008        6         2      5.0       3.0       1
#
#    PYBRP2  ... PMDA1C13  PMDA1C14  PMDA1C15 PPHY1A00  PPHY1B00  PPHY1C00  \
# 0     1.0  ...      2.0       3.0       3.0        3         1         0
# 1     1.0  ...      2.0       3.0       2.0        3         1         1
# 2     1.0  ...      3.0       3.0       3.0        2         1         7
# 3     1.0  ...      3.0       3.0       3.0        2         1         7
# 4     1.0  ...      3.0       3.0       2.0        3         5         7
#
#    PPHY2A00  PPHY2B00     ID  ID_w
# 0     155.0      43.0  1-1-1   1-1
# 1     163.0      67.0  2-1-1   2-1
# 2     158.0      60.0  3-1-1   3-1
# 3     158.0      60.0  3-2-1   3-2
# 4     162.0      46.0  4-1-1   4-1
#
# [5 rows x 211 columns]

# %% [markdown]
# ## **2) 컬럼명 정보 추출하기**

# %% [markdown]
# ### **변수의 설명 추출 딕셔너리**

# %%
# codebook에서 변수의 설명을 딕셔너리 형태로 만드는 함수이다.
# ex. {'HID': '가구 ID','PID': '개인 ID','SCLID': '학교코드','YONLINE': '온라인 조사 여부',...}

def get_variable_info(cookbooks):
    var_dict = {}
    cnt = 0
    for sheet, codebook in codebooks.items():
        var_dict[sheet] = {k:v for k, v in zip(codebook['변수명'],codebook['변수설명'])}

    # 저장
    with open(f'./datasets/variable_info.pkl', 'wb') as f:
        pickle.dump(var_dict, f)

    print('>>> 변수 설명 정보(개별) 저장 완료!')

    return var_dict

# %%
# 변수의 설명 추출 딕셔너리
variable_info = get_variable_info(codebooks)
# Out:
# >>> 변수 설명 정보(개별) 저장 완료!

# %%
# 예시
for x in variable_info.items():
    print(x)
# Out:
# ('e4', {'HID': '가구 ID', 'PID': '개인 ID', 'SCLID': '학교코드', 'YONLINE': '온라인 조사 여부', 'WEIGHTA1': '횡단면_원 가중치', 'WEIGHTA2': '횡단면_표준화 가중치', 'WEIGHTB1': '종단면_원 가중치', 'WEIGHTB2': '종단면_표준화 가중치', 'SIBLING': '[형제자매] 원패널과의 관계', 'SIBLING_T': '[형제자매] 원패널과의 관계_기타', 'SGRADE': '[형제자매] 형제자매 학년', 'SURVEY1': '조사 참여 여부_청소년', 'SURVEY2': '조사 참여 여부_보호자', 'COHORT': '코호트 구분', 'ARA1A': '시/도(학교 기준)', 'ARA2A': '도시규모(학교 기준)', 'ARA1B': '시/도(거주지 기준)', 'YTWIN': '쌍둥이 여부', 'YBRT1A': '생년', 'YBRT1B': '생월', 'YGENDER': '성별', 'YTIM1A01': '평일_기상(시)', 'YTIM1A02': '평일_기상(분)', 'YTIM1B01': '평일_취침(시)', 'YTIM1B02': '평일_취침(분)', 'YTIM1C01': '평일_수면의 질', 'YTIM1A03': '주말_기상(시)', 'YTIM1A04': '주말_기상(분)', 'YTIM1B03': '주말_취침(시)', 'YTIM1B04': '주말_취침(분)', 'YTIM1C02': '주말_수면의 질', 'YTIM1D01': '평일_부모님 대화시간', 'YTIM1D02': '주말_부모님 대화시간', 'YTIM1E01': '평일_학원 및 과외 시간', 'YTIM1E02': '주말_학원 및 과외 시간', 'YTIM1F01': '평일_인터넷 및 TV강의 시간', 'YTIM1F02': '주말_인터넷 및 TV강의 시간', 'YTIM1G01': '평일_방과 후 학교', 'YTIM1G02': '주말_방과 후 학교', 'YTIM1H01': '평일_스스로 공부하는 시간', 'YTIM1H02': '주말_스스로 공부하는 시간', 'YTIM1I01': '평일_독서 시간', 'YTIM1I02': '주말_독서 시간', 'YTIM1J01': '평일_운동 및 신체활동 시간', 'YTIM1J02': '주말_운동 및 신체활동 시간', 'YTIM1K01': '평일_스마트폰을 가지고 노는 시간', 'YTIM1K02': '주말_스마트폰을 가지고 노는 시간', 'YTIM1L01': '평일_컴퓨터를 가지고 노는 시간', 'YTIM1L02': '주말_컴퓨터를 가지고 노는 시간', 'YTIM1M01': '평일_TV를 시청하며 노는 시간', 'YTIM1M02': '주말_TV를 시청하며 노는 시간', 'YTIM1N01': '평일_이외에 친구들과 노는 시간', 'YTIM1N02': '주말_이외에 친구들과 노는 시간', 'YINT1A00': '지난 학기 전 과목 성적 수준', 'YINT1B00': '지난 학기 학교성적 만족 수준', 'YINT2A01': '나는 내가 하고 있는 공부의 의미와 목적을 분명히 안다', 'YINT2A02': '나는 공부란 도전해 볼만한 것이라고 생각한다', 'YINT2A03': '나는 공부를 하면 뿌듯해진다', 'YINT2A04': '나는 공부를 통해 자아실현을 할 수 있다고 생각한다', 'YINT2A05': '나는 공부할 때 힘이 나고 활기가 생긴다', 'YINT2A06': '나는 공부할 때 에너지가 생긴다', 'YINT2A07': '나는 공부할 때 정신적으로 힘이 난다', 'YINT2A08': '아침에 일어나면 수업 들으러 학교에 가고 싶다', 'YINT2A09': '나는 공부를 잘한다', 'YINT2A10': '나는 공부에 있어 누구에게도 뒤지지 않는다', 'YINT2A11': '나는 공부에 자신이 있다', 'YINT2A12': '나는 어려운 과제도 충분히 해결할 만한 능력이 있다', 'YINT2A13': '나는 공부할 때 내 주변의 다른 모든 것을 잊어버린다', 'YINT2A14': '나는 공부를 시작하면 푹 빠진다', 'YINT2A15': '공부를 하다보면 나도 모르게 집중할 때가 있다', 'YINT2A16': '나는 공부할 때 시간이 잘 간다', 'YFUR2A01': '아버지', 'YFUR2A02': '어머니', 'YFUR2A03': '형제ㆍ자매', 'YFUR2A04': '친척ㆍ친지', 'YFUR2A05': '학교 선생님', 'YFUR2A06': '상담교사', 'YFUR2A07': '학원/과외 선생님', 'YFUR2A08': '기타', 'YFUR2A08_T': '기타 (적을 것)', 'YPSY1A01': '전반적으로 볼 때, 나의 삶은 나의 이상에 가깝다', 'YPSY1A02': '내 삶의 상황들은 아주 좋다', 'YPSY1A03': '나는 내 삶에 만족한다', 'YPSY1A04': '지금까지 내 삶에서 내가 원하는 중요한 것들을 이루어 냈다', 'YPSY1A05': '만약 내 삶을 다시 살 수 있더라도, 나는 거의 아무것도 바꾸지 않을 것이다', 'YPSY2A01': '전반적으로 나는 …', 'YPSY2A02': '다른 사람과 비교했을 때 나는 …', 'YPSY2A03': '전반적으로 아주 행복한 사람들이 있다. 나는 …', 'YPSY2A04': '전반적으로 아주 불행한 사람들이 있다. 나는 …', 'YPSY3A01': '나는 나에게 만족한다', 'YPSY3A02': '때때로 나는 내가 어디에도 소용없는 사람이라고 생각한다', 'YPSY3A03': '나는 내가 장점이 많다고 느낀다', 'YPSY3A04': '나는 내가 적어도 다른 사람만큼 가치 있는 사람이라고 느낀다', 'YPSY3A05': '나는 내가 자랑스러워할 만한 것이 별로 없다고 느낀다', 'YPSY3A06': '때때로 나는 내가 쓸모없는 존재로 느껴진다', 'YPSY3A07': '나는 남들만큼의 일은 할 수 있다', 'YPSY3A08': '나는 나를 좀 더 존중할 수 있었으면 좋겠다', 'YPSY3A09': '나는 내가 실패자라고 느끼는 경향이 있다', 'YPSY3A10': '나는 나에 대해 긍정적인 태도를 지니고 있다', 'YPSY4A01': '칭찬을 받거나 벌을 받아도 금방 다시 주의가 산만해진다', 'YPSY4A02': '문제를 풀 때 문제를 끝까지 읽지 않는 편이다', 'YPSY4A03': '오랫동안 집중해야 하는 과제는 하고 싶지 않다', 'YPSY4A04': '연필이나 지우개 등 학용품을 잘 잃어버린다', 'YPSY4A05': '주의를 기울이지 않아서 실수를 하거나 사고를 낸다', 'YPSY4A06': '공부할 때 차분하게 앉아 있기 힘들다', 'YPSY4A07': '글자를 잘 빠뜨리고 쓰는 편이다', 'YPSY4B01': '작은 일에도 트집을 잡을 때가 있다', 'YPSY4B02': '남이 하는 일을 방해할 때가 있다', 'YPSY4B03': '내가 원하는 것을 못하게 하면 따지거나 덤빈다', 'YPSY4B04': '별 것 아닌 일로 싸우곤 한다', 'YPSY4B05': '하루 종일 화가 날 때가 있다', 'YPSY4B06': '아무 이유 없이 울 때가 있다', 'YPSY4C01': '깊이 잠들지 못하고 자다가 잠에서 깨곤 한다', 'YPSY4C02': '머리가 자주 아프다', 'YPSY4C03': '속이 자주 메슥거린다', 'YPSY4C04': '공부를 하면 배가 아플 때가 있다', 'YPSY4C05': '입맛이 없을 때가 있다', 'YPSY4C06': '자주 피곤하다', 'YPSY4C07': '숨쉬기 어려울 때가 있다', 'YPSY4C08': '자주 열이 나는 것처럼 느껴진다', 'YPSY4D01': '주위에 사람들이 많으면 어색하다', 'YPSY4D02': '부끄럼을 많이 탄다', 'YPSY4D03': '다른 사람들에게 내 의견을 분명하게 말하기 어렵다', 'YPSY4D04': '수줍어한다', 'YPSY4D05': '사람들 앞에 나서기를 싫어한다', 'YPSY4E01': '기운이 별로 없다', 'YPSY4E02': '불행하다고 생각하거나 슬퍼하고 우울해한다', 'YPSY4E03': '걱정이 많다', 'YPSY4E04': '죽고 싶은 생각이 든다', 'YPSY4E05': '울 ...
# ('m1', {'HID': '가구 ID', 'PID': '개인 ID', 'SCLID': '학교코드', 'YONLINE': '온라인 조사 여부', 'WEIGHTA1': '횡단면_원 가중치', 'WEIGHTA2': '횡단면_표준화 가중치', 'WEIGHTB1': '종단면_원 가중치', 'WEIGHTB2': '종단면_표준화 가중치', 'SIBLING': '[형제자매] 원패널과의 관계', 'SIBLING_T': '[형제자매] 원패널과의 관계_기타', 'SGRADE': '[형제자매] 형제자매 학년', 'SURVEY1': '조사 참여 여부_청소년', 'SURVEY2': '조사 참여 여부_보호자', 'COHORT': '코호트 구분', 'ARA1A': '시/도(학교 기준)', 'ARA2A': '도시규모(학교 기준)', 'ARA1B': '시/도(거주지 기준)', 'SCLTYP': '고등학교 유형', 'YTWIN': '쌍둥이 여부', 'YBRT1A': '생년', 'YBRT1B': '생월', 'YGENDER': '성별', 'YTIM1A01': '평일_기상(시)', 'YTIM1A02': '평일_기상(분)', 'YTIM1B01': '평일_취침(시)', 'YTIM1B02': '평일_취침(분)', 'YTIM1C01': '평일_수면의 질', 'YTIM1A03': '주말_기상(시)', 'YTIM1A04': '주말_기상(분)', 'YTIM1B03': '주말_취침(시)', 'YTIM1B04': '주말_취침(분)', 'YTIM1C02': '주말_수면의 질', 'YTIM1D01': '평일_부모님 대화시간', 'YTIM1D02': '주말_부모님 대화시간', 'YTIM1E01': '평일_학원 및 과외 시간', 'YTIM1E02': '주말_학원 및 과외 시간', 'YTIM1F01': '평일_인터넷 및 TV강의 시간', 'YTIM1F02': '주말_인터넷 및 TV강의 시간', 'YTIM1G01': '평일_방과 후 학교', 'YTIM1G02': '주말_방과 후 학교', 'YTIM1H01': '평일_스스로 공부하는 시간', 'YTIM1H02': '주말_스스로 공부하는 시간', 'YTIM1I01': '평일_독서 시간', 'YTIM1I02': '주말_독서 시간', 'YTIM1J01': '평일_운동 및 신체활동 시간', 'YTIM1J02': '주말_운동 및 신체활동 시간', 'YTIM1K01': '평일_스마트폰을 가지고 노는 시간', 'YTIM1K02': '주말_스마트폰을 가지고 노는 시간', 'YTIM1L01': '평일_컴퓨터를 가지고 노는 시간', 'YTIM1L02': '주말_컴퓨터를 가지고 노는 시간', 'YTIM1M01': '평일_TV를 시청하며 노는 시간', 'YTIM1M02': '주말_TV를 시청하며 노는 시간', 'YTIM1N01': '평일_이외에 친구들과 노는 시간', 'YTIM1N02': '주말_이외에 친구들과 노는 시간', 'YINT1A00': '지난 학기 전 과목 성적 수준', 'YINT1B00': '지난 학기 학교성적 만족 수준', 'YINT2A01': '나는 내가 하고 있는 공부의 의미와 목적을 분명히 안다', 'YINT2A02': '나는 공부란 도전해 볼만한 것이라고 생각한다', 'YINT2A03': '나는 공부를 하면 뿌듯해진다', 'YINT2A04': '나는 공부를 통해 자아실현을 할 수 있다고 생각한다', 'YINT2A05': '나는 공부할 때 힘이 나고 활기가 생긴다', 'YINT2A06': '나는 공부할 때 에너지가 생긴다', 'YINT2A07': '나는 공부할 때 정신적으로 힘이 난다', 'YINT2A08': '아침에 일어나면 수업 들으러 학교에 가고 싶다', 'YINT2A09': '나는 공부를 잘한다', 'YINT2A10': '나는 공부에 있어 누구에게도 뒤지지 않는다', 'YINT2A11': '나는 공부에 자신이 있다', 'YINT2A12': '나는 어려운 과제도 충분히 해결할 만한 능력이 있다', 'YINT2A13': '나는 공부할 때 내 주변의 다른 모든 것을 잊어버린다', 'YINT2A14': '나는 공부를 시작하면 푹 빠진다', 'YINT2A15': '공부를 하다보면 나도 모르게 집중할 때가 있다', 'YINT2A16': '나는 공부할 때 시간이 잘 간다', 'YINT2B01': '실력 차이를 내 힘으로 극복할 수는 없다고 생각한다', 'YINT2B02': '아무리 공부해도 내가 지금보다 더 잘할 수는 없다고 생각한다', 'YINT2B03': '내 힘으로 학업 문제를 해결할 수는 없다고 생각한다', 'YINT2B04': '공부를 잘하기 위하여 내가 할 수 있는 일이 없다고 생각한다', 'YINT2B05': '공부에 신경 쓰고 싶지 않다', 'YINT2B06': '공부를 왜 해야 하는지 관심도 없다', 'YINT2B07': '공부를 열심히 해야 하는 이유를 모르겠다', 'YINT2B08': '공부하고 싶은 의욕이 생기지 않는다', 'YINT2B09': '공부하는 것이 즐겁지 않다', 'YINT2B10': '수업을 듣거나 모둠활동을 하면서 유쾌함을 느끼지 못한다', 'YINT2B11': '학교에서 생활하면서 행복함을 느끼지 못한다', 'YINT2B12': '점수가 잘 나온다 해도 기쁘지 않다', 'YINT2B13': '시험기간이라도 공부에 전념하지 않는다', 'YINT2B14': '스스로 알아서 공부하지 않는다', 'YINT2B15': '수업에 적극적으로 참여하지 않는다', 'YINT2B16': '스스로 알아서 학습계획을 짜본 적이 없다', 'YFUR1A00': '향후 목표하는 학업 수준', 'YFUR1B00': '장래 희망직업 결정 여부', 'YFUR2A01': '아버지', 'YFUR2A02': '어머니', 'YFUR2A03': '형제ㆍ자매', 'YFUR2A04': '친척ㆍ친지', 'YFUR2A05': '학교 선생님', 'YFUR2A06': '상담교사', 'YFUR2A07': '학원/과외 선생님', 'YFUR2A08': '기타', 'YFUR2A08_T': '기타 (적을 것)', 'YFUR3A01': '나는 내 미래의 직업에 대해 많은 관심을 두지 못하고 있는 것 같다', 'YFUR3A02': '나는 내가 바라는 직업에 대해 별로 생각하지 않는다', 'YFUR3A03': '나는 정말 끌리는 일을 찾지 못하겠다', 'YFUR3B01': '나는 직업에 필요한 요건에 대해 아는 것이 거의 없다', 'YFUR3B02': '나는 내가 원하는 분야의 일을 하기 위해 어떻게 시작해야 할지 모르겠다', 'YFUR3B03': '나는 내가 하고 싶은 일을 위해 나 자신을 준비하는데 어려움을 겪고 있다', 'YFUR3B04': '나는 학교에서 어떤 과목을 이수해야 할지 모르겠다', 'YFUR3B05': '내가 세운 직업 계획이 현실적인지 모르겠다', 'YFUR3C01': '사람마다 나에게 하는 말이 달라 나는 어떤 분야의 일을 선택해야 할지 모르겠다', 'YFUR3C02': '나는 직업 선택을 계속 바꾸고 있다', 'YFUR3C03': '나는 내가 뭐가 되고 싶은지에 대해 자주 공상하지만 실제로 아직 직업을 선택하지는 못했다', 'YFUR3C04': '직업을 선택할 때 고려해야 할 것이 너무 많아 직업을 결정하는 것이 어렵다', 'YFUR3C05': '사람들이 자신이 하고 싶은 일에 어떻게 그렇게 확신을 갖는지 나는 이해할 수 없다', 'YPSY1A01': '전반적으로 볼 때, 나의 삶은 나의 이상에 가깝다', 'YPSY1A02': '내 삶의 상황들은 아주 좋다', 'YPSY1A03': '나는 내 삶에 만족한다', 'YPSY1A04': '지금까지 내 삶에서 내가 원하는 중요한 것들을 이루어 냈다', 'YPSY1A05': '만약 내 삶을 다시 살 수 있더라도, 나는 거의 아무것도 바꾸지 않을 것이다', 'YPSY2A01': '전반적으로 나는 …', 'YPSY2A02': '다른 사람과 비교했을 때 나는 …', 'YPSY2A03': '전반적으로 아주 행복한 사람들이 있다. 나는 …', 'YPSY2A04': '전반적으로 아주 불행한 사람들이 있다. 나는 …', 'YPSY3A01': '나는 나에게 만족한다', 'YPSY3A02': '때때로 나는 내가 어디에도 소 ...
(w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFGENDER6': '가구원 상세6 성별 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFBRTA6': '가구원 상세6 생년 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFBRTB6': '가구원 상세6 생월 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFRELATION7': '가구원 상세7 관계 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFGENDER7': '가구원 상세7 성별 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFBRTA7': '가구원 상세7 생년 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFBRTB7': '가구원 상세7 생월 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFRELATION8': '가구원 상세8 관계 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFGENDER8': '가구원 상세8 성별 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFBRTA8': '가구원 상세8 생년 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFBRTB8': '가구원 상세8 생월 (w1의 경우 가구정보를 활용하여 w2 이후의 변수 형태로 재구성)', 'PFRELATION9': '가구원 상세9 관계', 'PFGENDER9': '가구원 상세9 성별', 'PFBRTA9': '가구원 상세9 생년', 'PFBRTB9': '가구원 상세9 생월', 'PFAM1A00': '자녀와 함께사는 가구원', 'PFAM1A00_T': '자녀와 함께사는 가구원 기타', 'PFAM2A01': '자녀의 주양육자', 'PFAM2A01_T': '자녀의 주양육자 기타', 'PFAM2A02': '자녀의 학교 관련 일정을 주로 관리하는 보호자', 'PFAM2A02_T': '자녀의 학교 관련 일정을 주로 관리하는 보호자 기타', 'PFAM2A03': '자녀의 사교육 관련 일정을 주로 관리하는 보호자', 'PFAM2A03_T': '자녀의 사교육 관련 일정을 주로 관리하는 보호자 기타', 'PFAM2A04': '자녀의 교우관계 형성에 주로 관여하는 보호자', 'PFAM2 ...

# %% [markdown]
# ### **변수의 카테고리별 정보 딕셔너리**

# %%
# codebook에서 카테고리에 따른 변수들을 딕셔너리 형태로 만드는 함수이다.
# 카테고리 = ['대영역', '중영역', '소영역', '조사항목', '하위요인']
# ex. ('수면시간', ['YTIM1A02', 'YTIM1B01', 'YTIM1B02', 'YTIM1A03', 'YTIM1A04', 'YTIM1B03', 'YTIM1B04', 'YTIM1A01', 'YTIM1A02', 'YTIM1B01', 'YTIM1B02', 'YTIM1A03', 'YTIM1A04', 'YTIM1B03', 'YTIM1B04'])

def get_category_info(category, codebooks):
    total_dict = {}

    keys = codebooks.keys()
    for key in keys:
        cat_dict = {}
        info = codebooks[key].loc[codebooks[key][category]!='-',:]
        for i in range(info.shape[0]):
            cat, var = info.iloc[i,:][[category,'변수명']]

            cat = re.sub('(^\[)|(\]$)','',cat)

            if cat in cat_dict.keys():
                cat_dict[cat].append(var)
            else:
                cat_dict[cat] = [var]
        total_dict[key] = cat_dict

    return total_dict

# %%
# 변수의 카테고리별 정보 딕셔너리
bycat_info = {}
categories = ['대영역', '중영역', '소영역', '조사항목', '하위요인']

for category in categories:
    bycat_info[category] = get_category_info(category, codebooks)
    print(f'> {category}', end=' ')

# 저장
with open(f'./datasets/category_info.pkl', 'wb') as f:
    pickle.dump(bycat_info, f)

print(f'>>> 카테고리별 정보 저장 완료!')
# Out:
# > 대영역 > 중영역 > 소영역 > 조사항목 > 하위요인 >>> 카테고리별 정보 저장 완료!

# %%
# 예시
i = 0
for x in bycat_info.items():
    print(x)
    i += 1
    if i == 3: break
# Out:
 'YDIS1B06', 'YDIS1B07', 'YDIS1B08', 'YDIS1B09', 'YDIS1B10', 'YDIS1B11', 'YDIS1B12'], '재난 안전 인식': ['YDIS2A00', 'YDIS2B00'], '재난 안전 행동요령 인식': ['YDIS3A01', 'YDIS3A02', 'YDIS3A03', 'YDIS3A04', 'YDIS3A05', 'YDIS3A06', 'YDIS3A07', 'YDIS3A08', 'YDIS3A09', 'YDIS3A10', 'YDIS3A11', 'YDIS3A12'], '정서인식 역량': ['YRME1A01', 'YRME1A02', 'YRME1A03', 'YRME1A04', 'YRME1A05', 'YRME1A06', 'YRME1A07', 'YRME1A08', 'YRME1A09', 'YRME1A10', 'YRME1A11',  ...

# %% [markdown]
# ### **범주형 변수의 값 설명 추출 딕셔너리**

# %%
# codebook에서 변수가 범주형 자료일 때 값에 대한 설명을 딕셔너리 형태로 만드는 함수이다.
# ex. {'YONLINE', {0: 'TAPI 조사', 1: '온라인 조사'}

def get_value_info(file_path, sheet_name):
    value_dict = {}

    codebooks = pd.read_excel(file_path, sheet_name=sheet_name,skiprows=3,usecols=[4,5,6]).reset_index(drop=True)
    codebooks = codebooks.iloc[1:,:]
    codebooks = codebooks.loc[codebooks['값']!='-',:]

    codebooks = codebooks.replace(np.nan, '')

    for i in range(codebooks.shape[0]):
        var, val, desc = codebooks.iloc[i,:]

        if var != '':
            value_dict[var] = {val:desc}
            name = var
        else:
            value_dict[name].update({val:desc})

    return value_dict

# %%
file_path = 'KCYPS2018 Codebook.xlsx'

sheets = ['CB_e', 'CB_m', 'CB_p']

value_dict = {}
cnt = 0
for sheet in sheets:
    if len(value_dict) == 0:
        value_dict = get_value_info(file_path, 'CB_e')
    else:
        temp = get_value_info(file_path, 'CB_m')
        for key, val in temp.items():
            if key in value_dict.keys():
                if value_dict[key] != value_dict[key]:
                    cnt += 1
                else:
                    continue
            else:
                value_dict.update({key:val})

if cnt == 0:
    print('>>> 변수는 같으나 정보가 다른 건은 없습니다.')

   # 저장
    with open(f'./datasets/value_info.pkl', 'wb') as f:
        pickle.dump(value_dict, f)

    print('>>> 변수의 값 설명 정보(통합) 저장 완료!')
# Out:
# >>> 변수는 같으나 정보가 다른 건은 없습니다.
# >>> 변수의 값 설명 정보(통합) 저장 완료!

# %%
# 예시
i = 0
for x in value_dict.items():
    print(x)
    i += 1
    if i == 3: break
# Out:
# ('YONLINE', {0: 'TAPI 조사', 1: '온라인 조사'})
# ('SIBLING', {1: '형/오빠', 2: '누나/언니', 3: '남동생', 4: '여동생', 5: '기타'})
# ('SGRADE', {1: '초1', 2: '초2', 3: '초3', 4: '초4', 5: '초5', 6: '초6', 7: '중1', 8: '중2', 9: '중3', 10: '고1', 11: '고2', 12: '고3'})

# %% [markdown]
# ## **3) 카테고리별 정보(공통 변수) 추출하기**

# %% [markdown]
# * 초등과 중등 데이터를 합치기 위해 공통된 변수를 찾고자 한다.

# %%
common_var = list(set(variable_info['e4']) & set(variable_info['m1']))

# 변수의 카테고리별 정보 딕셔너리
bycat_common_info = {}
categories = ['대영역', '중영역', '소영역', '조사항목', '하위요인']

codebooks_common = {}

for k, v in codebooks.items():
    if k != 'p':
        is_include = v['변수명'].apply(lambda x: x in common_var)
        v = v.loc[is_include,:]

    codebooks_common[k] = v

for category in categories:
    bycat_common_info[category] = get_category_info(category, codebooks_common)
    print(f'> {category}', end=' ')

# 저장
with open(f'./datasets/category_common_info.pkl', 'wb') as f:
    pickle.dump(bycat_common_info, f)

print(f'>>> 카테고리별(공통변수) 정보 저장 완료!')
# Out:
# > 대영역 > 중영역 > 소영역 > 조사항목 > 하위요인 >>> 카테고리별(공통변수) 정보 저장 완료!

# %%
# 예시
i = 0
for x in bycat_common_info.items():
    print(x)
    i += 1
    if i == 3: break
# Out:
# ('대영역', {'e4': {'배경변인': ['ARA1A', 'ARA2A', 'ARA1B', 'YTWIN', 'YBRT1A', 'YBRT1B', 'YGENDER'], '개인발달': ['YTIM1A01', 'YTIM1A02', 'YTIM1B01', 'YTIM1B02', 'YTIM1C01', 'YTIM1A03', 'YTIM1A04', 'YTIM1B03', 'YTIM1B04', 'YTIM1C02', 'YTIM1D01', 'YTIM1D02', 'YTIM1E01', 'YTIM1E02', 'YTIM1F01', 'YTIM1F02', 'YTIM1G01', 'YTIM1G02', 'YTIM1H01', 'YTIM1H02', 'YTIM1I01', 'YTIM1I02', 'YTIM1J01', 'YTIM1J02', 'YTIM1K01', 'YTIM1K02', 'YTIM1L01', 'YTIM1L02', 'YTIM1M01', 'YTIM1M02', 'YTIM1N01', 'YTIM1N02', 'YINT1A00', 'YINT1B00', 'YINT2A01', 'YINT2A02', 'YINT2A03', 'YINT2A04', 'YINT2A05', 'YINT2A06', 'YINT2A07', 'YINT2A08', 'YINT2A09', 'YINT2A10', 'YINT2A11', 'YINT2A12', 'YINT2A13', 'YINT2A14', 'YINT2A15', 'YINT2A16', 'YFUR2A01', 'YFUR2A02', 'YFUR2A03', 'YFUR2A04', 'YFUR2A05', 'YFUR2A06', 'YFUR2A07', 'YFUR2A08', 'YFUR2A08_T', 'YPSY1A01', 'YPSY1A02', 'YPSY1A03', 'YPSY1A04', 'YPSY1A05', 'YPSY2A01', 'YPSY2A02', 'YPSY2A03', 'YPSY2A04', 'YPSY3A01', 'YPSY3A02', 'YPSY3A03', 'YPSY3A04', 'YPSY3A05', 'YPSY3A06', 'YPSY3A07', 'YPSY3A08', 'YPSY3A09', 'YPSY3A10', 'YPSY4A01', 'YPSY4A02', 'YPSY4A03', 'YPSY4A04', 'YPSY4A05', 'YPSY4A06', 'YPSY4A07', 'YPSY4B01', 'YPSY4B02', 'YPSY4B03', 'YPSY4B04', 'YPSY4B05', 'YPSY4B06', 'YPSY4C01', 'YPSY4C02', 'YPSY4C03', 'YPSY4C04', 'YPSY4C05', 'YPSY4C06', 'YPSY4C07', 'YPSY4C08', 'YPSY4D01', 'YPSY4D02', 'YPSY4D03', 'YPSY4D04', 'YPSY4D05', 'YPSY4E01', 'YPSY4E02', 'YPSY4E03', 'YPSY4E04', 'YPSY4E05', 'YPSY4E06', 'YPSY4E07', 'YPSY4E08', 'YPSY4E09', 'YPSY4E10', 'YPSY5A01', 'YPSY5A02', 'YPSY
AM1H02', 'YFAM1H03', 'YFAM1H04'], '양육태도': ['YFAM2A01', 'YFAM2A02', 'YFAM2A03', 'YFAM2A04', 'YFAM2B01', 'YFAM2B02', 'YFAM2B03', 'YFAM2B04', 'YFAM2C01', 'YFAM2C02', 'YFAM2C03', 'YFAM2C04', 'YFAM2D01', 'YFAM2D02', 'YFAM2D03', 'YFAM2D04', 'YFAM2E01', 'YFAM2E02', 'YFAM2E03', 'YFAM2E04', 'YFAM2F01', 'YFAM2F02', 'YFAM2F03', 'YFAM2F04'], '재난 안전 체감도': ['YDIS1A01', 'YDIS1A02', 'YDIS1A03', 'YDIS1A04', 'YDIS1A05', 'YDIS1A06', 'YDIS1A07', 'YDIS1A08', 'YDIS1A09', 'YDIS1A10', 'YDIS1A11', 'YDIS1A12', 'YDIS1B01', 'YDIS1B02', 'YDIS1B03', 'YDIS1B04', 'YDIS1B05', 'YDIS1B06', 'YDIS1B07', 'YDIS1B08', 'YDIS1B09', 'YDIS1B10', 'YDIS1B11', 'YDIS1B12'], '재난 안전 인식': ['YDIS2A00', 'YDIS2B00'], '재난 안전 행동요령 인식': ['YDIS3A01', 'YDIS3A02', 'YDIS3A03', 'YDIS3A04', 'YDIS3A05', 'YDIS3A06', 'YDIS3A07', 'YDIS3A08', 'YDIS3A09', 'YDIS3A10', 'YDIS3A11', 'YDIS3A12'], '정서인식 역량': ['YRME1A01', 'YRME1A02', 'YRME1A03', 'YRME1A04', 'YRME1A05', 'YRME1A06', 'YRME1A07', 'YRME1A08', 'YRME1A09', 'YRME1A10', 'YRME1A11',  ...

# %%
# # 데이터 분리(대상별)
# data_e4Y = {1: data['e4Yw1'], 2: data['e4Yw2'], 3: data['e4Yw3'], 4: data['e4Yw4']}
# data_e4P = {1: data['e4Pw1'], 2: data['e4Pw2'], 3: data['e4Pw3'], 4: data['e4Pw4']}
# data_m1Y = {1: data['m1Yw1'], 2: data['m1Yw2'], 3: data['m1Yw3'], 4: data['m1Yw4']}
# data_m1P = {1: data['m1Pw1'], 2: data['m1Pw2'], 3: data['m1Pw3'], 4: data['m1Pw4']}

# by_subject_data = {'e4Y': data_e4Y, 'e4P': data_e4P, 'm1Y': data_m1Y, 'm1P': data_m1P}

# with open('./datasets/by_subject_data.pkl', 'wb') as f:
#     pickle.dump(by_subject_data, f)

# %%
# # 데이터 분리(차수별)
# data_w1 = {'e4': data['e4Yw1'], 'e4p': data['e4Pw1'], 'm1': data['m1Yw1'], 'm1p': data['m1Pw1']}
# data_w2 = {'e4': data['e4Yw2'], 'e4p': data['e4Pw2'], 'm1': data['m1Yw2'], 'm1p': data['m1Pw2']}
# data_w3 = {'e4': data['e4Yw3'], 'e4p': data['e4Pw3'], 'm1': data['m1Yw3'], 'm1p': data['m1Pw3']}
# data_w4 = {'e4': data['e4Yw4'], 'e4p': data['e4Pw4'], 'm1': data['m1Yw4'], 'm1p': data['m1Pw4']}

# by_year_data = {'w1': data_w1, 'w2': data_w2, 'w3': data_w3, 'w4': data_w4}

# with open('./datasets/by_year_data.pkl', 'wb') as f:
#     pickle.dump(by_year_data, f)
